# %%
import pandas as pd

df = pd.read_csv('../data/processed/cleaned_train_set.csv', index_col=0, parse_dates=True)

df.head(5)
# Out:
#                       Series1   Series2   Series3   Series4   Series5  \
# Date
# 2012-01-01 00:00:00  0.458882 -1.358177  1.893863  1.022005 -1.810638
# 2012-01-01 00:01:00  0.398794 -1.356111  2.011162  1.104435 -1.807173
# 2012-01-01 00:02:00  0.480416 -1.354050  2.116713  1.134004 -1.803721
# 2012-01-01 00:03:00  0.319643 -1.351994  1.987292  0.996250 -1.800283
# 2012-01-01 00:04:00  0.361104 -1.349943  2.059825  1.041442 -1.796859
#
#                       Series6
# Date
# 2012-01-01 00:00:00 -0.792524
# 2012-01-01 00:01:00 -0.726880
# 2012-01-01 00:02:00 -0.816924
# 2012-01-01 00:03:00 -1.010524
# 2012-01-01 00:04:00 -1.010524

# %%
from preprocessing.regression_feature_engineering import RegressionFeatureEngineer

feature_engineer = RegressionFeatureEngineer(df)

df_features = (
    feature_engineer
    .create_lag_features(columns=df.columns, lags=[1, 2, 3])
    .create_rolling_averages(columns=df.columns, windows=[3, 7], stats=['mean', 'std'])
    .create_polynomial_features(columns=df.columns, degree=2)
    .get_engineered_data()
)

df_features.head(10)
df_features.columns
# Out:
#                      Series1_lag_1  Series1_lag_2  Series1_lag_3  \
# Date
# 2012-01-01 00:00:00            NaN            NaN            NaN
# 2012-01-01 00:01:00       0.458882            NaN            NaN
# 2012-01-01 00:02:00       0.398794       0.458882            NaN
# 2012-01-01 00:03:00       0.480416       0.398794       0.458882
# 2012-01-01 00:04:00       0.319643       0.480416       0.398794
# 2012-01-01 00:05:00       0.361104       0.319643       0.480416
# 2012-01-01 00:06:00       0.321572       0.361104       0.319643
# 2012-01-01 00:07:00       0.302223       0.321572       0.361104
# 2012-01-01 00:08:00       0.282828       0.302223       0.321572
# 2012-01-01 00:09:00       0.222920       0.282828       0.302223
#
#                      Series2_lag_1  Series2_lag_2  Series2_lag_3  \
# Date
# 2012-01-01 00:00:00            NaN            NaN            NaN
# 2012-01-01 00:01:00      -1.358177            NaN            NaN
# ...
